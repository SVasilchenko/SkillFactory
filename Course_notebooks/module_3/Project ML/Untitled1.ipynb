# %%
import pandas as pd
import numpy as np
import re

# %%
cities = pd.read_excel('Cities.xls')  
df = pd.read_csv('main_task_new.csv')
df.columns = ['id','city','style','city_rank','rating','price','num_of_reviews','reviews','url_ta','id_ta']

# %%
df = pd.merge(df, cities, on='city')
df
# Out:
#              id    city                                              style  \
# 0       id_5569   Paris            ['European', 'French', 'International']
# 1      id_10057   Paris                                                NaN
# 2      id_11291   Paris                                         ['French']
# 3       id_5459   Paris           ['Asian', 'Thai', 'Vegetarian Friendly']
# 4       id_9924   Paris                                            ['Pub']
# ...         ...     ...                                                ...
# 39995    id_651  Krakow                               ['Italian', 'Pizza']
# 39996    id_355  Krakow  ['Italian', 'Mediterranean', 'Vegetarian Frien...
# 39997    id_283  Krakow  ['Italian', 'Pizza', 'European', 'Vegetarian F...
# 39998    id_800  Krakow                                                NaN
# 39999    id_953  Krakow                                                NaN
#
#        city_rank  rating     price  num_of_reviews  \
# 0         5570.0     3.5  $$ - $$$           194.0
# 1        10059.0     4.5       NaN             4.0
# 2        11293.0     4.5  $$ - $$$            10.0
# 3         5460.0     3.5  $$ - $$$           132.0
# 4         9926.0     3.5         $            39.0
# ...          ...     ...       ...             ...
# 39995      652.0     4.0  $$ - $$$            28.0
# 39996      356.0     4.0  $$ - $$$           201.0
# 39997      284.0     4.0  $$ - $$$           340.0
# 39998      801.0     4.5       NaN            11.0
# 39999      954.0     3.5       NaN            11.0
#
#                                                  reviews  \
# 0      [['Good food at your doorstep', 'A good hotel ...
# 1                         [['Fab Food'], ['08/20/2011']]
# 2      [['A relaxing dinner in a very personal atmos....
# 3      [['Very good Thai Food but small Portions and....
# 4      [['English pub', 'Shameful'], ['02/14/2017', '...
# ...                                                  ...
# 39995  [['Warm and welcoming', 'Cozy, good food'], ['...
# 39996  [['Nice meal', 'Excellent food'], ['11/12/2017...
# 39997  [['Good food and friendly service', 'Nice, fri...
# 39998  [['Great snacks', "You won't be disappointed"]...
# 39999  [['Yummy', 'Very disorganized'], ['12/23/2017'...
#
#                                                   url_ta      id_ta    gdp  \
# 0      /Restaurant_Review-g187147-d1912643-Reviews-R_...   d1912643  46062
# 1      /Restaurant_Review-g187147-d2040769-Reviews-Le...   d2040769  46062
# 2      /Restaurant_Review-g187147-d3543081-Reviews-La...   d3543081  46062
# 3      /Restaurant_Review-g187147-d953033-Reviews-Cha...    d953033  46062
# 4      /Restaurant_Review-g187147-d5799345-Reviews-Th...   d5799345  46062
# ...                                                  ...        ...    ...
# 39995  /Restaurant_Review-g274772-d3626236-Reviews-Tr...   d3626236  34103
# 39996  /Restaurant_Review-g274772-d1929643-Reviews-La...   d1929643  34103
# 39997  /Restaurant_Review-g274772-d1098691-Reviews-Fa...   d1098691  34103
# 39998  /Restaurant_Review-g274772-d3899509-Reviews-Pi...   d3899509  34103
# 39999  /Restaurant_Review-g274772-d10810513-Reviews-R...  d10810513  34103
#
#       country  population
# 0      France        2161
# 1      France        2161
# 2      France        2161
# 3      France        2161
# 4      France        2161
# ...       ...         ...
# 39995  Poland         767
# 39996  Poland         767
# 39997  Poland         767
# 39998  Poland         767
# 39999  Poland         767
#
# [40000 rows x 13 columns]

# %%
df = pd.DataFrame([['NaN', 2, np.nan, 0],
                   [3, 4, np.nan, 1],
                   [np.nan, np.nan, np.nan, 5],
                   [np.nan, 3, np.nan, 4]],
                  columns=list("ABCD"))

# %%
for x in df:
    print(df[x])
# Out:
# 0    NaN
# 1      3
# 2    NaN
# 3    NaN
# Name: A, dtype: object
# 0    2.0
# 1    4.0
# 2    NaN
# 3    3.0
# Name: B, dtype: float64
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# Name: C, dtype: float64
# 0    0
# 1    1
# 2    5
# 3    4
# Name: D, dtype: int64

# %%
for index, row in df.iterrows():
    print(row)
# Out:
# A    NaN
# B      2
# C    NaN
# D      0
# Name: 0, dtype: object
# A      3
# B      4
# C    NaN
# D      1
# Name: 1, dtype: object
# A    NaN
# B    NaN
# C    NaN
# D      5
# Name: 2, dtype: object
# A    NaN
# B      3
# C    NaN
# D      4
# Name: 3, dtype: object

# %%
gen = (i for i in df.A.index if np.isnan(df.A[i]))

# %%
df.loc[4]['C']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     354                 try:
# --> 355                     return self._range.index(new_key)
#     356                 except ValueError as err:
#
# ValueError: 4 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-a9513f09d6f1> in <module>
# ----> 1 df.loc[4]['C']
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1057     def _get_label(self, label, axis: int):
#    1058         # GH#5667 this will fail if the label is not present in the axis.
# -> 1059         return self.obj.xs(label, axis=axis)
#    1060
#    1061     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3489             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3490         else:
# -> 3491             loc = self.index.get_loc(key)
#    3492
#    3493             if isinstance(loc, np.ndarray):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     355                     return self._range.index(new_key)
#     356                 except ValueError as err:
# --> 357                     raise KeyError(key) from err
#     358             raise KeyError(key)
#     359         return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 4

# %%
for i in gen:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-00bdf2d29331> in <module>
# ----> 1 for i in gen:
#       2     print(i)
#
# <ipython-input-54-53f6fb9a2431> in <genexpr>(.0)
# ----> 1 gen = (i for i in df.A.index if np.isnan(df.A[i]))
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
def cuisine_number(string):
    if pd.isnull(string):
        return 3
    else:
        return len(re.findall(r"\'[\w+\s*]+\'",str(string)))

# %%
string = "['Bar', 'Pub']"
cuisine_number(string)
# Out:
# 2

# %%
with open('readme.txt', 'w') as f:
    f.write('readme')
