# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
import numpy as np
import seaborn as sns

# %%
data_flats = pd.read_csv('data_flats.csv', sep=';')
data_flats.head()
# Out:
#    id  full_sq  life_sq  floor           sub_area  preschool_quota  \
# 0   1       43     27.0    4.0           Bibirevo           5001.0
# 1   2       34     19.0    3.0  Nagatinskij Zaton           3119.0
# 2   3       43     29.0    2.0     Tekstil'shhiki           1463.0
# 3   4       89     50.0    9.0             Mitino           6839.0
# 4   5       77     77.0    4.0          Basmannoe           3240.0
#
#    preschool_education_centers_raion  school_quota  \
# 0                                  5       11065.0
# 1                                  5        6237.0
# 2                                  4        5580.0
# 3                                  9       17063.0
# 4                                  7        7770.0
#
#    school_education_centers_raion  school_education_centers_top_20_raion  ...  \
# 0                               5                                      0  ...
# 1                               8                                      0  ...
# ...

# %%
train_df = pd.read_csv("train.csv", encoding = 'ISO-8859-1', low_memory = False)
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250306 entries, 0 to 250305
# Data columns (total 34 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   ticket_id                   250306 non-null  int64
#  1   agency_name                 250306 non-null  object
#  2   inspector_name              250306 non-null  object
#  3   violator_name               250272 non-null  object
#  4   violation_street_number     250306 non-null  float64
#  5   violation_street_name       250306 non-null  object
#  6   violation_zip_code          0 non-null       float64
#  7   mailing_address_str_number  246704 non-null  float64
#  8   mailing_address_str_name    250302 non-null  object
#  9   city                        250306 non-null  object
#  10  state                       250213 non-null  object
#  11  zip_code                    250305 non-null  object
# ...

# %%
na_value = vis_data.state.value_counts(ascending=False).index[0]
print(na_value)
#results = vis_data.state.fillna(na_value)
#results[results.isna()]
vis_data.state.fillna(na_value, inplace=True)
vis_data.state[vis_data.state.isna()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-69407257317d> in <module>
# ----> 1 na_value = vis_data.state.value_counts(ascending=False).index[0]
#       2 print(na_value)
#       3 #results = vis_data.state.fillna(na_value)
#       4 #results[results.isna()]
#       5 vis_data.state.fillna(na_value, inplace=True)
#
# NameError: name 'vis_data' is not defined

# %%
data_flats.dropna(axis=0, inplace=True)
data_flats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13652 entries, 0 to 30468
# Data columns (total 56 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     13652 non-null  int64
#  1   full_sq                                13652 non-null  int64
#  2   life_sq                                13652 non-null  float64
#  3   floor                                  13652 non-null  float64
#  4   sub_area                               13652 non-null  object
#  5   preschool_quota                        13652 non-null  float64
#  6   preschool_education_centers_raion      13652 non-null  int64
#  7   school_quota                           13652 non-null  float64
#  8   school_education_centers_raion         13652 non-null  int64
#  9   school_education_centers_top_20_raion  13652 non-null  int64
# ...

# %%
skaler = StandardScaler()
balance = np.array(vis_data.balance_due).reshape(-1,1)
skaler.fit_transform(balance).min().round(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-cb336dd2a6e5> in <module>
#       1 skaler = StandardScaler()
# ----> 2 balance = np.array(vis_data.balance_due).reshape(-1,1)
#       3 skaler.fit_transform(balance).min().round(5)
#
# NameError: name 'vis_data' is not defined

# %%
filtered = train_df.balance_due[train_df.balance_due > 0]**(1/2)

filtered.median() - filtered.mean()
# Out:
# 0.4525960609393067

# %%
data_flats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30469 entries, 0 to 30468
# Data columns (total 56 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     30469 non-null  int64
#  1   full_sq                                30469 non-null  int64
#  2   life_sq                                24086 non-null  float64
#  3   floor                                  30302 non-null  float64
#  4   sub_area                               30469 non-null  object
#  5   preschool_quota                        23781 non-null  float64
#  6   preschool_education_centers_raion      30469 non-null  int64
#  7   school_quota                           23784 non-null  float64
#  8   school_education_centers_raion         30469 non-null  int64
#  9   school_education_centers_top_20_raion  30469 non-null  int64
# ...

# %%
filtered = data_flats[data_flats.sub_area.isin(['Lefortovo','Perovo','Basmannoe','Bogorodskoe'])]
filtered
# Out:
#           id  full_sq  life_sq  floor     sub_area  preschool_quota  \
# 4          5       77     77.0    4.0    Basmannoe           3240.0
# 14        15       31     21.0    3.0    Lefortovo           1768.0
# 28        29       73     38.0   15.0  Bogorodskoe           3107.0
# 56        57       56     39.0    4.0  Bogorodskoe           3107.0
# 83        84       66     42.0    7.0    Basmannoe           3240.0
# ...      ...      ...      ...    ...          ...              ...
# 30254  30259       45     28.0   11.0       Perovo           2232.0
# 30331  30336       38     19.0    6.0    Lefortovo           1768.0
# 30401  30406       61     34.0    9.0    Lefortovo           1768.0
# 30438  30443       99     47.0    4.0    Basmannoe           3240.0
# 30452  30457       40     26.0    3.0  Bogorodskoe           3107.0
#
#        preschool_education_centers_raion  school_quota  \
# 4                                      7        7770.0
# ...

# %%
sns.boxplot(x='sub_area', y='price_doc', data=filtered)
# Out:
# <AxesSubplot:xlabel='sub_area', ylabel='price_doc'>

# %%
filtered = train_df[['balance_due','payment_amount']]
filtered
# Out:
#         balance_due  payment_amount
# 0             305.0             0.0
# 1              75.0           780.0
# 2               0.0             0.0
# 3               0.0             0.0
# 4               0.0             0.0
# ...             ...             ...
# 250301          0.0             0.0
# 250302          0.0             0.0
# 250303          0.0             0.0
# 250304          0.0             0.0
# 250305          0.0             0.0
#
# [250306 rows x 2 columns]

# %%
pf = PolynomialFeatures(3)
poly_features = pf.fit_transform(filtered)
poly_features.mean(axis=0).argmax()
# Out:
# 6

# %%
dates = pd.to_datetime(train_df.ticket_issued_date.dropna())
weekends = dates[dates.dt.weekday >=5]
len(weekends)
# Out:
# 1620

# %%
eco_dict = {'no_data}
